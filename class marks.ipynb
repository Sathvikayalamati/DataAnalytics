# %%
import pandas as pd

# %%
df=pd.read_csv("class_marks.csv")

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# 4     NaN    NaN
# ..    ...    ...
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0
#
# [86 rows x 12 columns]

# %%
 df.shape
# Out:
# (86, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %%
df.dtypes
# Out:
# Total      int64
# Q1aM4    float64
# Q1bM6    float64
# Q2aM6    float64
# Q2bM4    float64
# Q3aM5    float64
# Q3bM5    float64
# Q4aM3    float64
# Q4bM7    float64
# Q5M10    float64
# Q6aM4    float64
# Q6bM6    float64
# dtype: object

# %%
 df.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %%
 df.head(7)
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# 5     20    4.0    6.0    6.0    4.0    NaN    NaN    NaN    NaN    NaN
# 6     25    3.0    4.0    NaN    2.0    5.0    5.0    NaN    NaN    6.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN
# 5    NaN    NaN
# 6    NaN    NaN

# %%
df.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0

# %%
df.tail(8)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 78     33    2.0    3.0    6.0    4.0    5.0    5.0    NaN    NaN    8.0
# 79     27    2.0    6.0    NaN    3.0    2.0    5.0    NaN    NaN    9.0
# 80     31    4.0    6.0    6.0    2.0    2.0    5.0    NaN    NaN    6.0
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 78    NaN    NaN
# 79    NaN    NaN
# 80    NaN    NaN
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0

# %%
df.shape
# Out:
# (86, 12)

# %%
 df=pd.read_csv("class_marks.csv",skiprows = 1)

# %%
df
# Out:
#     37    4    5    6  4.1    2    1  Unnamed: 7  5.1     8  4.2  6.1
# 0   32  4.0  3.0  4.0  3.0  NaN  NaN         3.0  6.0   9.0  NaN  NaN
# 1   33  4.0  5.0  5.0  1.0  5.0  5.0         NaN  NaN   8.0  NaN  NaN
# 2   24  4.0  6.0  6.0  3.0  2.0  2.0         NaN  NaN   NaN  2.0  NaN
# 3   36  3.0  6.0  4.0  4.0  5.0  4.0         NaN  NaN  10.0  NaN  NaN
# 4   20  4.0  6.0  6.0  4.0  NaN  NaN         NaN  NaN   NaN  NaN  NaN
# ..  ..  ...  ...  ...  ...  ...  ...         ...  ...   ...  ...  ...
# 80  32  3.0  6.0  3.0  4.0  5.0  3.0         NaN  NaN   NaN  4.0  6.0
# 81  27  2.0  2.0  5.0  3.0  NaN  NaN         NaN  NaN   7.0  3.0  5.0
# 82  37  4.0  6.0  6.0  2.0  NaN  NaN         NaN  NaN   9.0  4.0  6.0
# 83  28  4.0  NaN  5.0  4.0  5.0  4.0         NaN  NaN   6.0  NaN  NaN
# 84  29  4.0  6.0  NaN  NaN  NaN  NaN         3.0  5.0   7.0  1.0  4.0
#
# [85 rows x 12 columns]

# %%
df=pd.read_csv("class_marks.csv",skiprows = 5)

# %%
 df.shape
# Out:
# (81, 12)

# %%
import pandas as pd
df=pd.read_csv("class_marks.csv",skiprows =[2,4,6])

# %%
df=pd.read_csv("class_marks.csv",skipfooter=3)
# Out:
# C:\Users\yalam\AppData\Local\Temp\ipykernel_12852\2906626353.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("class_marks.csv",skipfooter=3)

# %%
df[df.Total<12]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 11      8    2.0    2.0    NaN    3.0    1.0    NaN    NaN    NaN    NaN
# 23      9    4.0    3.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 69      3    1.0    NaN    1.0    NaN    NaN    NaN    1.0    NaN    NaN
#
#     Q6aM4  Q6bM6
# 11    NaN    NaN
# 23    1.0    1.0
# 69    NaN    NaN

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"]

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 78     33    2.0    3.0    6.0    4.0    5.0    5.0    NaN    NaN    8.0
# 79     27    2.0    6.0    NaN    3.0    2.0    5.0    NaN    NaN    9.0
# 80     31    4.0    6.0    6.0    2.0    2.0    5.0    NaN    NaN    6.0
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
#
#     Q6aM4  Q6bM6    Q1
# 0     4.0    6.0   9.0
# 1     NaN    NaN   7.0
# 2     NaN    NaN   9.0
# 3     2.0    NaN  10.0
# 4     NaN    NaN   9.0
# ..    ...    ...   ...
# 78    NaN    NaN   5.0
# 79    NaN    NaN   8.0
# 80    NaN    NaN  10.0
# 81    4.0    6.0   9.0
# 82    3.0    5.0   4.0
#
# [83 rows x 13 columns]

# %%
df["Q2"]=df["Q2aM6"]+df["Q2bM4"]
df["Q3"]=df["Q3aM5"]+df["Q3bM5"]
df["Q4"]=df["Q4aM3"]+df["Q4bM7"]
df["Q5"]=df["Q5M10"]
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 78     33    2.0    3.0    6.0    4.0    5.0    5.0    NaN    NaN    8.0
# 79     27    2.0    6.0    NaN    3.0    2.0    5.0    NaN    NaN    9.0
# 80     31    4.0    6.0    6.0    2.0    2.0    5.0    NaN    NaN    6.0
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0     4.0    6.0   9.0  10.0   3.0  NaN   8.0  10.0
# 1     NaN    NaN   7.0   7.0   NaN  9.0   9.0   NaN
# 2     NaN    NaN   9.0   6.0  10.0  NaN   8.0   NaN
# 3     2.0    NaN  10.0   9.0   4.0  NaN   NaN   NaN
# 4     NaN    NaN   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...    ...   ...   ...   ...  ...   ...   ...
# 78    NaN    NaN   5.0  10.0  10.0  NaN   8.0   NaN
# 79    NaN    NaN   8.0   NaN   7.0  NaN   9.0   NaN
# 80    NaN    NaN  10.0   8.0   7.0  NaN   6.0   NaN
# 81    4.0    6.0   9.0   7.0   8.0  NaN   NaN  10.0
# 82    3.0    5.0   4.0   8.0   NaN  NaN   7.0   8.0
#
# [83 rows x 18 columns]

# %%
 df.drop("Q1aM4",axis=1)
# Out:
#     Total  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  Q6aM4  \
# 0      37    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0    4.0
# 1      32    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0    NaN
# 2      33    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0    NaN
# 3      24    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN    2.0
# 4      36    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0    NaN
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 78     33    3.0    6.0    4.0    5.0    5.0    NaN    NaN    8.0    NaN
# 79     27    6.0    NaN    3.0    2.0    5.0    NaN    NaN    9.0    NaN
# 80     31    6.0    6.0    2.0    2.0    5.0    NaN    NaN    6.0    NaN
# 81     32    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN    4.0
# 82     27    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0    3.0
#
#     Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0     6.0   9.0  10.0   3.0  NaN   8.0  10.0
# 1     NaN   7.0   7.0   NaN  9.0   9.0   NaN
# 2     NaN   9.0   6.0  10.0  NaN   8.0   NaN
# 3     NaN  10.0   9.0   4.0  NaN   NaN   NaN
# 4     NaN   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 78    NaN   5.0  10.0  10.0  NaN   8.0   NaN
# 79    NaN   8.0   NaN   7.0  NaN   9.0   NaN
# 80    NaN  10.0   8.0   7.0  NaN   6.0   NaN
# 81    6.0   9.0   7.0   8.0  NaN   NaN  10.0
# 82    5.0   4.0   8.0   NaN  NaN   7.0   8.0
#
# [83 rows x 17 columns]

# %%
df.drop("Q1bM6",axis=1)
# Out:
#     Total  Q1aM4  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  Q6aM4  \
# 0      37    4.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0    4.0
# 1      32    4.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0    NaN
# 2      33    4.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0    NaN
# 3      24    4.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN    2.0
# 4      36    3.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0    NaN
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 78     33    2.0    6.0    4.0    5.0    5.0    NaN    NaN    8.0    NaN
# 79     27    2.0    NaN    3.0    2.0    5.0    NaN    NaN    9.0    NaN
# 80     31    4.0    6.0    2.0    2.0    5.0    NaN    NaN    6.0    NaN
# 81     32    3.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN    4.0
# 82     27    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0    3.0
#
#     Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0     6.0   9.0  10.0   3.0  NaN   8.0  10.0
# 1     NaN   7.0   7.0   NaN  9.0   9.0   NaN
# 2     NaN   9.0   6.0  10.0  NaN   8.0   NaN
# 3     NaN  10.0   9.0   4.0  NaN   NaN   NaN
# 4     NaN   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 78    NaN   5.0  10.0  10.0  NaN   8.0   NaN
# 79    NaN   8.0   NaN   7.0  NaN   9.0   NaN
# 80    NaN  10.0   8.0   7.0  NaN   6.0   NaN
# 81    6.0   9.0   7.0   8.0  NaN   NaN  10.0
# 82    5.0   4.0   8.0   NaN  NaN   7.0   8.0
#
# [83 rows x 17 columns]

# %%
df.drop(["Q1aM4","Q1bM6","Q2aM6","Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"],axis=1)
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  NaN   8.0  10.0
# 1      32   7.0   7.0   NaN  9.0   9.0   NaN
# 2      33   9.0   6.0  10.0  NaN   8.0   NaN
# 3      24  10.0   9.0   4.0  NaN   NaN   NaN
# 4      36   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 78     33   5.0  10.0  10.0  NaN   8.0   NaN
# 79     27   8.0   NaN   7.0  NaN   9.0   NaN
# 80     31  10.0   8.0   7.0  NaN   6.0   NaN
# 81     32   9.0   7.0   8.0  NaN   NaN  10.0
# 82     27   4.0   8.0   NaN  NaN   7.0   8.0
#
# [83 rows x 7 columns]

# %%
df=df.replace(38,40)

# %%
df.Total.value_counts()
# Out:
# 40    10
# 36     7
# 32     6
# 34     5
# 37     4
# 27     4
# 29     4
# 25     4
# 24     4
# 33     4
# 20     4
# 28     3
# 31     3
# 22     3
# 26     3
# 30     3
# 35     3
# 39     2
# 21     2
# 17     2
# 14     1
# 9      1
# 19     1
# 8      1
# 18     1
# 3      1
# Name: Total, dtype: int64

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"]
df["Q2"]=df["Q2aM6"]+df["Q2bM4"]
df["Q3"]=df["Q3aM5"]+df["Q3bM5"]
df["Q4"]=df["Q4aM3"]+df["Q4bM7"]
df["Q5"]=df["Q5M10"]
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0     4.0    6.0   9.0  10.0   3.0  NaN   8.0  10.0
# 1     NaN    NaN   7.0   7.0   NaN  9.0   9.0   NaN
# 2     NaN    NaN   9.0   6.0  10.0  NaN   8.0   NaN
# 3     2.0    NaN  10.0   9.0   4.0  NaN   NaN   NaN
# 4     NaN    NaN   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...    ...   ...   ...   ...  ...   ...   ...
# 81    4.0    6.0   9.0   7.0   8.0  NaN   NaN  10.0
# 82    3.0    5.0   4.0   8.0   NaN  NaN   7.0   8.0
# 83    4.0    6.0  10.0   8.0   NaN  NaN   9.0  10.0
# 84    NaN    NaN   NaN   9.0   9.0  NaN   6.0   NaN
# 85    1.0    4.0  10.0   NaN   NaN  8.0   7.0   5.0
#
# [86 rows x 18 columns]

# %%
df.drop(["Q1aM4","Q1bM6","Q2aM6","Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"],axis=1)
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  NaN   8.0  10.0
# 1      32   7.0   7.0   NaN  9.0   9.0   NaN
# 2      33   9.0   6.0  10.0  NaN   8.0   NaN
# 3      24  10.0   9.0   4.0  NaN   NaN   NaN
# 4      36   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  NaN   NaN  10.0
# 82     27   4.0   8.0   NaN  NaN   7.0   8.0
# 83     37  10.0   8.0   NaN  NaN   9.0  10.0
# 84     28   NaN   9.0   9.0  NaN   6.0   NaN
# 85     29  10.0   NaN   NaN  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]
df[(df.Total==40) & (df.Q6==10)]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 33     40    NaN    NaN    6.0    4.0    5.0    5.0    3.0    7.0    NaN
# 55     40    3.0    5.0    6.0    4.0    NaN    NaN    NaN    NaN   10.0
# 59     40    2.0    6.0    6.0    4.0    5.0    5.0    NaN    NaN   10.0
# 73     40    4.0    6.0    NaN    NaN    5.0    5.0    3.0    NaN   10.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3    Q4    Q5    Q6
# 33    4.0    6.0   NaN  10.0  10.0  10.0   NaN  10.0
# 55    4.0    6.0   8.0  10.0   NaN   NaN  10.0  10.0
# 59    4.0    6.0   8.0  10.0  10.0   NaN  10.0  10.0
# 73    4.0    6.0  10.0   NaN  10.0   NaN  10.0  10.0

# %%
import pandas as pd
df=pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# 4     NaN    NaN
# ..    ...    ...
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0
#
# [86 rows x 12 columns]

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"]
df["Q2"]=df["Q2aM6"]+df["Q2bM4"]
df["Q3"]=df["Q3aM5"]+df["Q3bM5"]
df["Q4"]=df["Q4aM3"]+df["Q4bM7"]
df["Q5"]=df["Q5M10"]
df["Q6"]=df["Q6aM4"]+df["Q6bM6"]
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q5    Q6
# 0     4.0    6.0   9.0  10.0   3.0  NaN   8.0  10.0
# 1     NaN    NaN   7.0   7.0   NaN  9.0   9.0   NaN
# 2     NaN    NaN   9.0   6.0  10.0  NaN   8.0   NaN
# 3     2.0    NaN  10.0   9.0   4.0  NaN   NaN   NaN
# 4     NaN    NaN   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...    ...   ...   ...   ...  ...   ...   ...
# 81    4.0    6.0   9.0   7.0   8.0  NaN   NaN  10.0
# 82    3.0    5.0   4.0   8.0   NaN  NaN   7.0   8.0
# 83    4.0    6.0  10.0   8.0   NaN  NaN   9.0  10.0
# 84    NaN    NaN   NaN   9.0   9.0  NaN   6.0   NaN
# 85    1.0    4.0  10.0   NaN   NaN  8.0   7.0   5.0
#
# [86 rows x 18 columns]

# %%
df=df.drop(["Q1aM4","Q1bM6","Q2aM6","Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"],axis=1)

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
#df['Q1']=df['Q1aM4']+df["Q1bM6"]
plt.hist(df['Q1'],color='red',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %%
plt.hist(df["Q2"],color='yellow',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %%
plt.hist(df["Q3"],color='orange',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %%
plt.hist(df["Q4"],color='green',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %%
plt.hist(df["Q5"],color='purple',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %%
df.plot.scatter(x = 'Q1', y = 'Total',color='blue',s=30)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='blue',edgecolors='red',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %%
df.boxplot(by='Q1', column =['Total'], grid = False,color='Green')
plt.title("Boxplot of Q1")
plt.ylabel("Total")
plt.show()

# %%
df.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
df["Q1"].plot(kind='pie',subplots=True,figsize=(8,10))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')
